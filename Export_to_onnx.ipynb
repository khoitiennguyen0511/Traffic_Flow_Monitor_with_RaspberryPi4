# %%
# !pip install -q ultralytics==8.3.19 onnx==1.19.0 onnxslim==0.1.70
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 7.2 MB/s eta 0:00:00

# %%
# Download best.pt
# !gdown 1EPdPKw0wOiW1C6eHcByVI27_1G2Jz3ys
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EPdPKw0wOiW1C6eHcByVI27_1G2Jz3ys
# To: /content/best.pt
# 100% 6.23M/6.23M [00:00<00:00, 39.5MB/s]

# %%
from ultralytics import YOLO

pt_path = "/content/best.pt"

model = YOLO(pt_path)
onnx_path = model.export(
    format="onnx",
    imgsz=384,
    opset=19,
    simplify=True
)
print("ONNX saved at:", onnx_path)
# Out:
# Ultralytics 8.3.19 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/best.pt' with input shape (1, 3, 384, 384) BCHW and output shape(s) (1, 9, 3024) (5.9 MB)
#
# ONNX: starting export with onnx 1.19.0 opset 19...
# ONNX: slimming with onnxslim 0.1.71...
# ONNX: export success ✅ 0.9s, saved as '/content/best.onnx' (11.6 MB)
#
# Export complete (1.2s)
# Results saved to /content
# Predict:         yolo predict task=detect model=/content/best.onnx imgsz=384
# Validate:        yolo val task=detect model=/content/best.onnx imgsz=384 data=/content/datasets/data.yaml
# Visualize:       https://netron.app
# ONNX saved at: /content/best.onnx
